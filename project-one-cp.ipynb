# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import requests
import time
import gmaps
import numpy as np
import scipy.stats as stats

import warnings
warnings.filterwarnings('ignore')

#list api keys here
from config import (api_key, gkey, sd_api_key, app_id)

state = 'Oklahoma'
state_code = 40
state_abbr = 'OK'

# %%
url = 'http://api.census.gov/data/2010/sf1?get=P0010001,NAME&for=county:*&in=state:40&key=' + api_key
response = requests.get(url).json()
county_name = []
county_code = []
census_variable_code = []
counter = 0;
for county in response:
    if (counter > 0):
        county_name.append(county[1])
        county_code.append(county[3])
        census_variable_code.append(county[0])
    counter = counter + 1
    
all_counties = {"County" : county_name,
               "County Code" : county_code,
               "Census Code" : census_variable_code}

all_counties_df = pd.DataFrame(all_counties)
all_counties_df.head()
# Out:
#            County County Code Census Code
# 0    Adair County         001       22683
# 1  Alfalfa County         003        5642
# 2    Atoka County         005       14182
# 3   Beaver County         007        5636
# 4  Beckham County         009       22119

# %%
url = 'http://api.census.gov/data/2010/sf1?get=P0010001,P0040003&for=zip+code+tabulation+area:*&in=state:40'
response = requests.get(url).json()
#print (response)
census_variable_p0010001 = []
census_variable_p0040003 = []
zip_code = []
counter = 0
for data in response:
    if (counter > 0):
        census_variable_p0010001.append(data[0])
        census_variable_p0040003.append(data[1])
        zip_code.append(data[3])
    counter = counter + 1

zip_codes_for_state = {"Census Code" : census_variable_p0010001,
                      "Census Code (P0040003)" : census_variable_p0040003,
                      "Zip Code" : zip_code}
zip_codes_for_state_df = pd.DataFrame(zip_codes_for_state)
zip_codes_for_state_df.head()
# Out:
#   Census Code Census Code (P0040003) Zip Code
# 0         146                     64    67950
# 1        1062                     45    73002
# 2       20617                   1417    73003
# 3         857                     29    73004
# 4        9541                   1013    73005

# %%
file_one = "./Resources/UnemploymentReport.csv"

income_df = pd.read_csv(file_one)
house_income = income_df[["Name", "Median Household Income (2016)"]]
house_income = house_income.dropna(how='any')

# %%
cities = house_income["Name"]
g_lat = []
g_lon= []
g_name = []

for city in cities:
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}').format(city, gkey)
    geo_data = requests.get(target_url).json()
    g_name.append(city)
    g_lat.append(geo_data["results"][0]["geometry"]["location"]["lat"])
    g_lon.append(geo_data["results"][0]["geometry"]["location"]["lng"])

# %%
g_dict = {"Name": g_name,
          "g_lat": g_lat,
          "g_lon": g_lon}

g_df = pd.DataFrame(g_dict)

# %%
final_table = pd.merge(house_income, g_df, on="Name", how="left")
final_table

final_table.to_csv("./Resources/final_household_income.csv", index=False, header = True)

# %%
gmaps.configure(api_key=gkey)

# %%
locations = final_table[["g_lat", "g_lon"]].astype(float)

household_income = final_table["Median Household Income (2016)"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=household_income, 
                                 dissipating=False, max_intensity=100000,
                                 point_radius = 1)


heat_layer.dissipating = False
heat_layer.max_intensity = 100000
heat_layer.point_radius = .5

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
crime_data = pd.read_csv('./Resources/crime-report.csv', encoding="utf-8")
crime_data_ok = crime_data[crime_data['state_abbr'] == 'OK']
crime_data_processed = pd.DataFrame()
crime_data_processed['Agency Name'] = crime_data_ok['agency_name']
crime_data_processed['County'] = crime_data_ok['primary_county']
crime_data_processed['FIPS'] = crime_data_ok['primary_county_fips']
clean_df = crime_data_processed.dropna()
grouped_county_crime = clean_df.groupby(['County'])
#print(grouped_county_crime.count().reset_index())

# %%
highschool_dropout_data = pd.read_csv('./Resources/EducationReport-hd.csv', encoding="utf-8")
hs_data_processed = pd.DataFrame()
#highschool_dropout_data.head()
hs_data_processed['County'] = highschool_dropout_data['Unnamed: 1']
hs_data_processed['FIPS'] = highschool_dropout_data['Unnamed: 0']
hs_data_processed['Dropout Percentage'] = highschool_dropout_data['Unnamed: 8']

clean_hs_df = hs_data_processed.dropna()
temp_df = clean_hs_df[clean_hs_df['County'] != 'Name']
temp_df2 = temp_df[temp_df['County'] != 'Oklahoma']

county_name = []
for grade in temp_df2['County']:
    county_nm = grade.split(",")[0]
    county = county_nm.split(" ")[0]
    county_name.append(county)
    

temp_df2['County'] = county_name
temp_df2['Dropout Percentage'] = temp_df2['Dropout Percentage'].str.replace('%', '')
temp_df2.head()
#print(temp_df2)
# Out:
# C:\Users\SWATI KHARKAR\Anaconda3\envs\UCB-Python\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\SWATI KHARKAR\Anaconda3\envs\UCB-Python\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     County   FIPS Dropout Percentage
# 3    Adair  40001               20.5
# 4  Alfalfa  40003               11.5
# 5    Atoka  40005               18.2
# 6   Beaver  40007               15.8
# 7  Beckham  40009               15.5

# %%
school_name = []
rating = []
low_grade = []
high_grade = []
school_level = []
county = []
district = []
year = []
#for loop that will go through school per page and add info to dictionary
for x in range(1,10):
    count = 50 #every new page the counter equals 1
    #calls the URL and gets json file
    request_url =  f"https://api.schooldigger.com/v1.1/rankings/schools/{state_abbr}?page={x}&perPage={count}&appID={app_id}&appKey={sd_api_key}"
    response = requests.get(request_url).json()
    #print(response)
    schools = response['schoolList']
    for school in schools:
        name = school['schoolName']
        school_name.append(name)
        try:
            rating.append(school['rankHistory'][0]['rank'])
            low_grade.append(school['lowGrade'])
            high_grade.append(school['highGrade'])
            school_level.append(school['schoolLevel'])
            county.append(school['county']['countyName'])
            district.append(school['district']['districtName'])
            print(f"Processed | {name}")
        except TypeError:
            print(f"Not Processed | {name}")
            
        x = x + 1 #page increases

#dictionary that will hold all data
school_dict = {"School Name": school_name,
              "Ratings": rating,
              "Low Grade": low_grade,
              "High Grade": high_grade,
              "Level": school_level,
              "County": county,
              "District": district}

#makes dictionary into DataFrame
school_df = pd.DataFrame(school_dict)
school_df.head()
# Out:
# Processed | Centennial Elementary School
# Processed | Grove Valley Elementary School
# Processed | Chisholm Elementary School
# Processed | Westwood Elementary School
# Processed | Cleveland Elementary School
# Processed | North Intermediate School
# Processed | Frontier Elementary School
# Processed | Sadler Arts Academy
# Processed | Prairie Vale Elementary School
# Processed | Pamela Hodson Elementary School
# Processed | Lakeview Elementary School
# Processed | South Lake Elementary School
# Processed | McKinley Elementary School
# Processed | Spring Creek Elementary School
# Processed | Plainview Intermediate Elementary School
# Processed | McCord Public School
# Processed | Heritage Elementary
# Processed | Southeast Elementary School
# Processed | Oakridge Elementary School
# Processed | Henry Zarrow International School
# Processed | Sangre Ridge Elementary School
# Processed | Wilson Elementary School
# Processed | Chisholm Elementary School
# Processed | West Field Elementary School
# Processed | Prague Elementary School
# Processed | Fisher Elementary School
# Processed | Northeast Elementary School
# 4     Cleveland Elementary School        5        PK          5  Elementary
#
#       County    District
# 0   Oklahoma      Edmond
# 1   Oklahoma  Deer Creek
# 2   Oklahoma      Edmond
# 3      Payne  Stillwater
# 4  Cleveland      Norman

# %%
edu_crime = pd.merge(clean_df, temp_df2, how ="left", on="County")
edu_crime_gb = edu_crime.groupby(['County', 'Dropout Percentage']).count().reset_index()
edu_crime_gb.head()
# Out:
#     County Dropout Percentage  Agency Name  FIPS_x  FIPS_y
# 0    Adair               20.5            4       4       4
# 1  Alfalfa               11.5            4       4       4
# 2    Atoka               18.2            5       5       5
# 3   Beaver               15.8            2       2       2
# 4  Beckham               15.5            4       4       4

# %%
#Education VS Crime
plt.figure(num=None, figsize=(8,5), dpi=80)
#print(edu_crime_gb["Dropout Percentage"])
perc = [float(line) for line in edu_crime_gb["Dropout Percentage"]]
plt.scatter(edu_crime_gb["FIPS_x"],perc,marker="o",edgecolors="black")
plt.title("Education( HIghschool Droupouts) and Crime rate correlation in Oklahoma (by counties)")
plt.ylabel("Dropout Percentage")
#plt.ylim(-100, 150)
plt.xlabel("Count of crime")
#plt.xticks([])
#plt.xlim(-80, 100)

plt.grid(zorder=0)
plt.savefig("EducationVsCrimeRate.png")
plt.show()

# %%
house_income= "./Resources/final_household_income.csv"
house_income = pd.read_csv(house_income)
house_income.head()

county_name = []
for entry in house_income['Name']:
    county_nm = entry.split(",")[0]
    county = county_nm.split(" ")[0]
    county_name.append(county)

house_income['County'] = county_name    
house_income.head()
# Out:
#                  Name  Median Household Income (2016)      g_lat       g_lon  \
# 0    Adair County, OK                         33632.0  35.912731  -94.645035
# 1  Alfalfa County, OK                         53695.0  36.743592  -98.396494
# 2    Atoka County, OK                         36766.0  34.450990  -95.983258
# 3   Beaver County, OK                         53493.0  36.744019 -100.529612
# 4  Beckham County, OK                         47407.0  35.268727  -99.634135
#
#     County
# 0    Adair
# 1  Alfalfa
# 2    Atoka
# 3   Beaver
# 4  Beckham

# %%
inc_crime = pd.merge(house_income, crime_data_processed, how ="left", on="County")

grouped_inc= inc_crime.groupby(['County', 'Median Household Income (2016)'])
print(grouped_inc.count().reset_index())
# Out:
#           County  Median Household Income (2016)  Name  g_lat  g_lon  \
# 0          Adair                         33632.0     4      4      4
# 1        Alfalfa                         53695.0     4      4      4
# 2          Atoka                         36766.0     5      5      5
# 3         Beaver                         53493.0     2      2      2
# 4        Beckham                         47407.0     4      4      4
# 5         Blaine                         44229.0     6      6      6
# 6          Bryan                         39219.0     9      9      9
# 7          Caddo                         40296.0     7      7      7
# 8       Canadian                         68291.0     7      7      7
# 9         Carter                         47966.0     5      5      5
# 10      Cherokee                         36297.0     4      4      4
# 11       Choctaw                         32458.0     5      5      5
# 12      Cimarron                         44000.0     3      3      3
# 13     Cleveland                         61275.0     9      9      9
# 14          Coal                         41111.0     2      2      2
# 15      Comanche                         48493.0     7      7      7
# 16        Cotton                         43019.0     3      3      3
# 17         Craig                         42781.0     4      4      4
# 18         Creek                         45630.0    10     10     10
# 19        Custer                         43247.0     4      4      4
# 20      Delaware                         39144.0     7      7      7
# 21         Dewey                         49398.0     3      3      3
# 22         Ellis                         51745.0     2      2      2
# 23      Garfield                         49841.0     6      6      6
# 24        Garvin                         40978.0     8      8      8
# 25         Grady                         55552.0     6      6      6
# 26         Grant                         48118.0     2      2      2
# 27         Greer                         35231.0     3      3      3
# 28        Harmon                         36703.0     2      2      2
# 29        Harper                         48559.0     3      3      3
# ..           ...                             ...   ...    ...    ...
# 47     McCurtain                         32664.0     1      1      1
# 48      McIntosh                         36903.0     1      1      1
# 49        Murray                         48008.0     3      3      3
# 50      Muskogee                         40581.0     7      7      7
# 51         Noble                         50316.0     3      3      3
# 52        Nowata                         41800.0     3      3      3
# 53      Okfuskee                         35106.0     5      5      5
# 54      Oklahoma                         51082.0    25     25     25
# 55      Okmulgee                         38446.0     7      7      7
# 56         Osage                         46074.0     8      8      8
# 57        Ottawa                         39210.0     7      7      7
# 58        Pawnee                         44619.0     4      4      4
# 59         Payne                         42035.0     7      7      7
# 60     Pittsburg                         44520.0     8      8      8
# 61      Pontotoc                         44212.0     5      5      5
# 62  Pottawatomie                         42453.0     5      5      5
# 63    Pushmataha                         34222.0     3      3      3
# 64         Roger                         54629.0     1      1      1
# 65        Rogers                         62622.0     9      9      9
# 66      Seminole                         36671.0     6      6      6
# 67      Sequoyah                         39629.0     6      6      6
# 68      Stephens                         44505.0     4      4      4
# 69         Texas                         50993.0     6      6      6
# 70       Tillman                         36350.0     4      4      4
# 71         Tulsa                         51476.0    14     14     14
# 72       Wagoner                         61882.0     4      4      4
# 73    Washington                         52283.0     5      5      5
# 74       Washita                         45642.0     5      5      5
# 75         Woods                         50441.0     3      3      3
# 76      Woodward                         57403.0     4      4      4
#
#     Agency Name  FIPS
# 0             4     4
# 1             4     4
# 2             5     5
# 3             2     2
# 4             4     4
# 5             6     6
# 6             9     9
# 7             7     7
# 8             7     7
# 9             5     5
# 10            4     4
# 11            5     5
# 12            3     3
# 13            9     9
# 14            2     2
# 15            7     7
# 16            3     3
# 17            4     4
# 18           10    10
# 19            4     4
# 20            7     7
# 21            3     3
# 22            2     2
# 23            6     6
# 24            8     8
# 25            6     6
# 26            2     2
# 27            3     3
# 28            2     2
# 29            3     3
# ..          ...   ...
# 47            0     0
# 48            0     0
# 49            3     3
# 50            7     7
# 51            3     3
# 52            3     3
# 53            5     5
# 54           25    25
# 55            7     7
# 56            8     8
# 57            7     7
# 58            4     4
# 59            7     7
# 60            8     8
# 61            5     5
# 62            5     5
# 63            3     3
# 64            0     0
# 65            9     9
# 66            6     6
# 67            6     6
# 68            4     4
# 69            6     6
# 70            4     4
# 71           14    14
# 72            4     4
# 73            5     5
# 74            5     5
# 75            3     3
# 76            4     4
#
# [77 rows x 7 columns]

# %%
#Income VS Crime
#print(inc_crime.head())
inc_crime_2 = grouped_inc.count().reset_index()
plt.figure(num=None, figsize=(15,5), dpi=80)
plt.scatter(inc_crime_2["Name"],inc_crime_2["Median Household Income (2016)"],marker="o",edgecolors="black")
plt.title("Income and Crime rate correlation in Oklahoma (by counties)")
plt.ylabel("Income")
#plt.ylim(-100, 150)
plt.xlabel("Crime Rates")
#plt.xlim(-80, 100)

plt.grid(True)
plt.savefig("IncomeVsCrimeRate.png")
#final_table["house income"]
plt.show()

# %%
inc_edu = pd.merge(house_income, school_df, how ="left", on="County")

edu_inc_clean= inc_edu.dropna()
grouped_inc_edu= edu_inc_clean.groupby(['County'])
grouped_inc_edu.head()
# Out:
#                       Name  Median Household Income (2016)      g_lat  \
# 0         Adair County, OK                         33632.0  35.912731
# 1         Adair County, OK                         33632.0  35.912731
# 2         Adair County, OK                         33632.0  35.912731
# 4         Atoka County, OK                         36766.0  34.450990
# 6       Beckham County, OK                         47407.0  35.268727
# 7       Beckham County, OK                         47407.0  35.268727
# 8       Beckham County, OK                         47407.0  35.268727
# 9        Blaine County, OK                         44229.0  35.882549
# 10        Bryan County, OK                         39219.0  33.902127
# 11        Bryan County, OK                         39219.0  33.902127
# 12        Bryan County, OK                         39219.0  33.902127
# 13        Caddo County, OK                         40296.0  35.105560
# 14        Caddo County, OK                         40296.0  35.105560
# 15        Caddo County, OK                         40296.0  35.105560
# 16     Canadian County, OK                         68291.0  35.559378
# 17     Canadian County, OK                         68291.0  35.559378
# 18     Canadian County, OK                         68291.0  35.559378
# 19     Canadian County, OK                         68291.0  35.559378
# 20     Canadian County, OK                         68291.0  35.559378
# 28       Carter County, OK                         47966.0  34.199625
# 29       Carter County, OK                         47966.0  34.199625
# 30       Carter County, OK                         47966.0  34.199625
# 31       Carter County, OK                         47966.0  34.199625
# 32     Cherokee County, OK                         36297.0  35.899473
# 33     Cherokee County, OK                         36297.0  35.899473
# 34     Cherokee County, OK                         36297.0  35.899473
# 35     Cherokee County, OK                         36297.0  35.899473
# 36     Cherokee County, OK                         36297.0  35.899473
# 37      Choctaw County, OK                         32458.0  33.985147
# 39    Cleveland County, OK                         61275.0  35.254964
# ..                     ...                             ...        ...
# 325    Sequoyah County, OK                         39629.0  35.515532
# 326    Sequoyah County, OK                         39629.0  35.515532
# 327    Stephens County, OK                         44505.0  34.520347
# 328    Stephens County, OK                         44505.0  34.520347
# 329    Stephens County, OK                         44505.0  34.520347
# 330    Stephens County, OK                         44505.0  34.520347
# 331    Stephens County, OK                         44505.0  34.520347
# 333       Texas County, OK                         50993.0  36.830132
# 334     Tillman County, OK                         36350.0  34.447835
# 335       Tulsa County, OK                         51476.0  36.159347
# 336       Tulsa County, OK                         51476.0  36.159347
# 337       Tulsa County, OK                         51476.0  36.159347
# 338       Tulsa County, OK                         51476.0  36.159347
# 339       Tulsa County, OK                         51476.0  36.159347
# 395     Wagoner County, OK                         61882.0  35.919240
# 396     Wagoner County, OK                         61882.0  35.919240
# 397     Wagoner County, OK                         61882.0  35.919240
# 398     Wagoner County, OK                         61882.0  35.919240
# 399     Wagoner County, OK                         61882.0  35.919240
# 400  Washington County, OK                         52283.0  36.677098
# 401  Washington County, OK                         52283.0  36.677098
# 402  Washington County, OK                         52283.0  36.677098
# 403  Washington County, OK                         52283.0  36.677098
# 404  Washington County, OK                         52283.0  36.677098
# 407     Washita County, OK                         45642.0  35.323403
# 408       Woods County, OK                         50441.0  36.718186
# 409    Woodward County, OK                         57403.0  36.413792
# 410    Woodward County, OK                         57403.0  36.413792
# 410  -99.367308    Woodward           Cedar Heights Elementary School
# 411  -99.367308    Woodward           Highland Park Elementary School
# 412  -99.367308    Woodward             Horace Mann Elementary School
#
#      Ratings Low Grade High Grade       Level      District
# 0      175.0        PK          8  Elementary          Zion
# 1      376.0        PK          8  Elementary      Maryetta
# 2      392.0        PK          6  Elementary     Westville
# 4      334.0        PK          8  Elementary         Atoka
# 6      125.0        PK          8  Elementary       Merritt
# 7      335.0        PK          5  Elementary         Sayre
# 8      366.0         3          4  Elementary      Elk City
# 9      212.0        PK          5  Elementary       Watonga
# 10     157.0         4          6  Elementary       Colbert
# 11     274.0        PK          5  Elementary          Silo
# 12     282.0         4          6  Elementary        Durant
# 13      68.0        PK          6  Elementary      Carnegie
# 14     141.0        PK          5  Elementary        Hinton
# 15     401.0        PK          5  Elementary      Anadarko
# 16      11.0         4          5  Elementary         Yukon
# 17      28.0         K          4  Elementary      Piedmont
# 18      46.0        PK          4  Elementary      Piedmont
# 19      76.0         K          4  Elementary      Piedmont
# 20     107.0         4          5  Elementary         Yukon
# 28      15.0         3          5  Elementary     Plainview
# 29      73.0         3          5  Elementary    Lone Grove
# 30     280.0         3          5  Elementary       Dickson
# 31     323.0         1          5  Elementary       Ardmore
# 32     102.0         K          5  Elementary     Tahlequah
# 33     167.0        PK          8  Elementary       Woodall
# 34     265.0         K          5  Elementary     Tahlequah
# 35     298.0         K          5  Elementary     Tahlequah
# 36     324.0        PK          8  Elementary    Grand View
# 37     402.0         4          5  Elementary          Hugo
# 39       5.0        PK          5  Elementary        Norman
# ..       ...       ...        ...         ...           ...
# 325    231.0        PK          4  Elementary       Muldrow
# 326    289.0         3          5  Elementary      Sallisaw
# 327     39.0         K          5  Elementary        Duncan
# 328    173.0        PK          6  Elementary        Empire
# 329    179.0         K          5  Elementary        Duncan
# 330    228.0        PK          5  Elementary        Marlow
# 331    246.0        PK          5  Elementary      Comanche
# 333    382.0         3          4  Elementary        Guymon
# 334    254.0        PK          5  Elementary     Frederick
# 335      6.0         4          6  Elementary         Bixby
# 336     10.0        PK          5  Elementary        Owasso
# 337     18.0        PK          4  Elementary         Jenks
# 338     20.0        PK          5  Elementary         Tulsa
# 339     27.0        PK          5  Elementary        Owasso
# 395     60.0        PK          5  Elementary  Broken Arrow
# 396    208.0         4          6  Elementary        Coweta
# 397    247.0         4          6  Elementary        Coweta
# 398    378.0        PK          5  Elementary  Broken Arrow
# 399    399.0         4          5  Elementary       Wagoner
# 400    106.0        PK          5  Elementary  Bartlesville
# 401    111.0        PK          5  Elementary  Bartlesville
# 402    132.0        PK          5  Elementary  Bartlesville
# 403    138.0        PK          5  Elementary         Dewey
# 404    211.0        PK          5  Elementary  Caney Valley
# 407     83.0        PK          6  Elementary       Cordell
# 408    210.0         4          5  Elementary          Alva
# 409     67.0        PK          8  Elementary     Mooreland
# 410    192.0         2          5  Elementary      Woodward
# 411    214.0         2          5  Elementary      Woodward
# 412    321.0         2          5  Elementary      Woodward
#
# [189 rows x 11 columns]

# %%
#Income VS Education
plt.figure(num=None, figsize=(8,5), dpi=80)
plt.scatter(edu_inc_clean["Median Household Income (2016)"],edu_inc_clean["Ratings"],marker="o",edgecolors="black")
# 4301            Walters Police Department      Cotton  40033.0
# 4397      Washita County Sheriff's Office     Washita  40149.0
# 4414            Waynoka Police Department       Woods  40151.0
# 4438            Wetumka Police Department      Hughes  40063.0
# 4441          Wilburton Police Department     Latimer  40077.0
# 4528        Woods County Sheriff's Office       Woods  40151.0
#
#                                    School Name  Ratings Low Grade High Grade  \
# 1                  Ward Elementary School East    157.0         4          6
# 2                       Silo Elementary School    274.0        PK          5
# 3        Durant Intermediate Elementary School    282.0         4          6
# 4                           Zion Public School    175.0        PK          8
# 5                       Maryetta Public School    376.0        PK          8
# 6                  Westville Elementary School    392.0        PK          6
# 7                      Homer Elementary School    113.0        PK          5
# 8                      Latta Elementary School    139.0        PK          5
# 9                       Byng Elementary School    193.0         4          6
# 10                Washington Elementary School    396.0         3          4
# 11                  Fairland Elementary School    198.0        PK          5
# 12             Nichols Upper Elementary School    241.0         4          5
# 13                 Alexander Elementary School    286.0        PK          5
# 14                    Prague Elementary School     25.0        PK          5
# 15                 Park Road Elementary School    230.0         3          6
# 16                    Meeker Elementary School    238.0        PK          5
# 18                     Homer Elementary School    113.0        PK          5
# 22                    Navajo Elementary School    185.0        PK          6
# 23                   Lincoln Elementary School    210.0         4          5
# 26                  Carnegie Elementary School     68.0        PK          6
# 27                    Hinton Elementary School    141.0        PK          5
# 28                   Mission Elementary School    401.0        PK          5
# 29                   Brantly Elementary School    272.0        PK          5
# 30                  Carnegie Elementary School     68.0        PK          6
# 31                    Hinton Elementary School    141.0        PK          5
# 34    Plainview Intermediate Elementary School     15.0         3          5
# 35              Lone Grove Intermediate School     73.0         3          5
# 36             Dickson Upper Elementary School    280.0         3          5
# 37                   Lincoln Elementary School    323.0         1          5
# 38                    Panama Elementary School    195.0        PK          6
# ...                                        ...      ...       ...        ...
# 3053                Pawhuska Elementary School    363.0         3          8
# 3055  Cleveland Intermediate Elementary School    284.0         3          5
# 3056                  Pawnee Elementary School    304.0        PK          5
# 3057  Cleveland Intermediate Elementary School    284.0         3          5
# 3076                   Perry Elementary School    224.0        PK          6
# 3158                 Brantly Elementary School    272.0        PK          5
# 3364                  Konawa Elementary School    153.0        PK          5
# 3365               Northwood Elementary School    337.0         4          6
# 3367                         Hugo Intermediate    402.0         4          5
# 3372                  Konawa Elementary School    153.0        PK          5
# 3379                 Cordell Elementary School     83.0        PK          6
# 3403                  Hobart Elementary School    301.0        PK          5
# 3404                  Nowata Elementary School     55.0        PK          5
# 3574                 Stigler Elementary School    356.0        PK          4
# 3583                        Zion Public School    175.0        PK          8
# 3584                    Maryetta Public School    376.0        PK          8
# 3593                   Atoka Elementary School    334.0        PK          8
# 3597    Sulphur Intermediate Elementary School    213.0         3          5
# 3629                 Walters Elementary School    116.0        PK          5
# 3630                 Academy Elementary School    382.0         3          4
# 3711               Frederick Elementary School    254.0        PK          5
# 3712               Frederick Elementary School    254.0        PK          5
# 3907                   Atoka Elementary School    334.0        PK          8
# 4289                  Vinita Elementary School    390.0        PK          5
# 4301                 Walters Elementary School    116.0        PK          5
# 4397                 Cordell Elementary School     83.0        PK          6
# 4414                 Lincoln Elementary School    210.0         4          5
# 4438                                Thomas Ies    271.0         4          8
# 4441               Wilburton Elementary School    285.0        PK          5
# 4528                 Lincoln Elementary School    210.0         4          5
#
#            Level     District
# 1     Elementary      Colbert
# 2     Elementary         Silo
# 3     Elementary       Durant
# 4     Elementary         Zion
# 5     Elementary     Maryetta
# 6     Elementary    Westville
# 7     Elementary         Byng
# 8     Elementary        Latta
# 9     Elementary         Byng
# 10    Elementary          Ada
# 11    Elementary     Fairland
# 12    Elementary        Miami
# 13    Elementary     Commerce
# 14    Elementary       Prague
# 15    Elementary     Chandler
# 16    Elementary       Meeker
# 18    Elementary         Byng
# 22    Elementary       Navajo
# 23    Elementary         Alva
# 26    Elementary     Carnegie
# 27    Elementary       Hinton
# 28    Elementary     Anadarko
# 29    Elementary      Antlers
# 30    Elementary     Carnegie
# 31    Elementary       Hinton
# 34    Elementary    Plainview
# 35    Elementary   Lone Grove
# 36    Elementary      Dickson
# 37    Elementary      Ardmore
# 38    Elementary       Panama
# ...          ...          ...
# 3053  Elementary     Pawhuska
# 3055  Elementary    Cleveland
# 3056  Elementary       Pawnee
# 3057  Elementary    Cleveland
# 3076  Elementary        Perry
# 3158  Elementary      Antlers
# 3364  Elementary       Konawa
# 3365  Elementary     Seminole
# 3367  Elementary         Hugo
# 3372  Elementary       Konawa
# 3379  Elementary      Cordell
# 3403  Elementary       Hobart
# 3404  Elementary       Nowata
# 3574  Elementary      Stigler
# 3583  Elementary         Zion
# 3584  Elementary     Maryetta
# 3593  Elementary        Atoka
# 3597  Elementary      Sulphur
# 3629  Elementary      Walters
# 3630  Elementary       Guymon
# 3711  Elementary    Frederick
# 3712  Elementary    Frederick
# 3907  Elementary        Atoka
# 4289  Elementary       Vinita
# 4301  Elementary      Walters
# 4397  Elementary      Cordell
# 4414  Elementary         Alva
# 4438  Elementary  Holdenville
# 4441  Elementary    Wilburton
# 4528  Elementary         Alva
#
# [285 rows x 9 columns]

# %%
plt.figure(num=None, figsize=(8,5), dpi=80)
plt.scatter(crime_edu_clean["FIPS"],crime_edu_clean["Ratings"],marker="o",edgecolors="black")
plt.title("Crime and School Rating correlation in Oklahoma (by counties)")
plt.ylabel("School Rating")
plt.xlabel("Crime Ratings")


plt.grid(True)
plt.savefig("CrimeVsSchoolRating.png")
plt.show()

# %%
#boxplot - final hypothesis- Crime impacts Income
sample_inc_crime = inc_crime.iloc[np.random.choice(np.arange(len(inc_crime)), 20, False)]
sample_inc_crime.head()

#sample_inc_crime.boxplot("FIPS", by="Median Household Income (2016)", figsize=(20, 10))
# Out:
#                     Name  Median Household Income (2016)      g_lat  \
# 384  Woodward County, OK                         57403.0  36.413792
# 203     Major County, OK                         51607.0  36.347967
# 229    Nowata County, OK                         41800.0  36.734439
# 37      Caddo County, OK                         40296.0  35.105560
# 101    Custer County, OK                         43247.0  35.671082
#
#          g_lon    County                     Agency Name     FIPS
# 384 -99.367308  Woodward     Mooreland Police Department  40153.0
# 203 -98.528161     Major   Major County Sheriff's Office  40093.0
# 229 -95.645795    Nowata  Nowata County Sheriff's Office  40105.0
# 37  -98.308844     Caddo      Carnegie Police Department  40015.0
# 101 -98.924534    Custer  Custer County Sheriff's Office  40039.0

# %%
# Extract individual groups
#print(sample_inc_crime)
set1 = sample_inc_crime.iloc[10:]
set2 = sample_inc_crime.iloc[:10]

# Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(set1['Median Household Income (2016)'], 10, density=True, alpha=0.7, label="set1")
plt.hist(set2['Median Household Income (2016)'], 10, density=True, alpha=0.7, label="set2")
plt.axvline(set1['Median Household Income (2016)'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(set2['Median Household Income (2016)'].mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend() 

stats.ttest_ind(set1['Median Household Income (2016)'], set2['Median Household Income (2016)'], equal_var=False)
# Out:
# Ttest_indResult(statistic=1.0337765215422514, pvalue=0.33152285019581973)

# %%
sample_edu_inc = edu_inc_clean.iloc[np.random.choice(np.arange(len(edu_inc_clean)), 20, False)]
sample_edu_inc.head()

#sample_edu_inc.boxplot("Ratings", by="Median Household Income (2016)", figsize=(20, 10))
# Out:
#                     Name  Median Household Income (2016)      g_lat  \
# 153   Lincoln County, OK                         44914.0  35.634265
# 376     Tulsa County, OK                         51476.0  36.159347
# 259  Oklahoma County, OK                         51082.0  35.603832
# 367     Tulsa County, OK                         51476.0  36.159347
# 14      Caddo County, OK                         40296.0  35.105560
#
#          g_lon    County                           School Name  Ratings  \
# 153 -96.835100   Lincoln              Meeker Elementary School    238.0
# 376 -95.940971     Tulsa  Collinsville Upper Elementary School    252.0
# 259 -97.351656  Oklahoma  West Nichols Hills Elementary School    384.0
# 367 -95.940971     Tulsa               Eliot Elementary School    170.0
# 14  -98.308844     Caddo              Hinton Elementary School    141.0
#
#     Low Grade High Grade       Level       District
# 153        PK          5  Elementary         Meeker
# 376         4          5  Elementary   Collinsville
# 259        PK          6  Elementary  Oklahoma City
# 367        PK          5  Elementary          Tulsa
# 14         PK          5  Elementary         Hinton

# %%
print(sample_edu_inc)
# Out:
#                      Name  Median Household Income (2016)      g_lat  \
# 153    Lincoln County, OK                         44914.0  35.634265
# 376      Tulsa County, OK                         51476.0  36.159347
# 259   Oklahoma County, OK                         51082.0  35.603832
# 367      Tulsa County, OK                         51476.0  36.159347
# 14       Caddo County, OK                         40296.0  35.105560
# 9       Blaine County, OK                         44229.0  35.882549
# 407    Washita County, OK                         45642.0  35.323403
# 330   Stephens County, OK                         44505.0  34.520347
# 98       Creek County, OK                         45630.0  35.836249
# 315     Rogers County, OK                         62622.0  36.389807
# 96       Creek County, OK                         45630.0  35.836249
# 196   Oklahoma County, OK                         51082.0  35.603832
# 205   Oklahoma County, OK                         51082.0  35.603832
# 170   Marshall County, OK                         41669.0  34.010335
# 165  McCurtain County, OK                         32664.0  34.148171
# 206   Oklahoma County, OK                         51082.0  35.603832
# 215   Oklahoma County, OK                         51082.0  35.603832
# 380      Tulsa County, OK                         51476.0  36.159347
# 383      Tulsa County, OK                         51476.0  36.159347
# 220   Oklahoma County, OK                         51082.0  35.603832
#
#          g_lon     County                           School Name  Ratings  \
# 153 -96.835100    Lincoln              Meeker Elementary School    238.0
# 376 -95.940971      Tulsa  Collinsville Upper Elementary School    252.0
# 259 -97.351656   Oklahoma  West Nichols Hills Elementary School    384.0
# 367 -95.940971      Tulsa               Eliot Elementary School    170.0
# 14  -98.308844      Caddo              Hinton Elementary School    141.0
# 9   -98.396494     Blaine             Watonga Elementary School    212.0
# 407 -98.924534    Washita             Cordell Elementary School     83.0
# 330 -97.872160   Stephens              Marlow Elementary School    228.0
# 98  -96.322607      Creek              Kiefer Elementary School    220.0
# 315 -95.645795     Rogers            Westside Elementary School    188.0
# 96  -96.322607      Creek             Freedom Elementary School     98.0
# 196 -97.351656   Oklahoma          Centennial Elementary School      1.0
# 205 -97.351656   Oklahoma         Earl Harris Elementary School     38.0
# 170 -96.792236   Marshall            Kingston Elementary School    205.0
# 165 -94.810596  McCurtain             Central Elementary School    291.0
# 206 -97.351656   Oklahoma                 Oakdale Public School     42.0
# 215 -97.351656   Oklahoma       Harvest Hills Elementary School    121.0
# 380 -95.940971      Tulsa       Patrick Henry Elementary School    269.0
# 383 -95.940971      Tulsa         Aspen Creek Elementary School    315.0
# 220 -97.351656   Oklahoma        Russell Babb Elementary School    148.0
#
#     Low Grade High Grade       Level       District
# 153        PK          5  Elementary         Meeker
# 376         4          5  Elementary   Collinsville
# 259        PK          6  Elementary  Oklahoma City
# 367        PK          5  Elementary          Tulsa
# 14         PK          5  Elementary         Hinton
# 9          PK          5  Elementary        Watonga
# 407        PK          6  Elementary        Cordell
# 330        PK          5  Elementary         Marlow
# 98         PK          6  Elementary         Kiefer
# 315        PK          5  Elementary      Claremore
# 96         PK          5  Elementary        Sapulpa
# 196        PK          5  Elementary         Edmond
# 205        PK          5  Elementary        Bethany
# 170        PK          5  Elementary       Kingston
# 165         2          5  Elementary         Idabel
# 206        PK          8  Elementary        Oakdale
# 215        PK          5  Elementary    Putnam City
# 380        PK          5  Elementary          Tulsa
# 383        PK          5  Elementary   Broken Arrow
# 220         4          5  Elementary         Harrah

# %%
set1 = sample_edu_inc.iloc[10:]
set2 = sample_edu_inc.iloc[:10]

print(set1['Median Household Income (2016)'])
print(set2['Median Household Income (2016)'])
# Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(set1['Median Household Income (2016)'], 10, density=True, alpha=0.7, label="set1")
plt.hist(set2['Median Household Income (2016)'], 10, density=True, alpha=0.7, label="set2")
plt.axvline(set1['Median Household Income (2016)'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(set2['Median Household Income (2016)'].mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend() 

stats.ttest_ind(set1['Median Household Income (2016)'], set2['Median Household Income (2016)'])
# Out:
# 96     45630.0
# 196    51082.0
# 205    51082.0
# 170    41669.0
# 165    32664.0
# 206    51082.0
# 215    51082.0
# 380    51476.0
# 383    51476.0
# 220    51082.0
# Name: Median Household Income (2016), dtype: float64
# 153    44914.0
# 376    51476.0
# 259    51082.0
# 367    51476.0
# 14     40296.0
# 9      44229.0
# 407    45642.0
# 330    44505.0
# 98     45630.0
# 315    62622.0
# Name: Median Household Income (2016), dtype: float64
# Ttest_indResult(statistic=-0.12665403368003017, pvalue=0.9006183025299941)
